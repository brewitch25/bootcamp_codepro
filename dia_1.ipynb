# %%
'''
# Challenge 1
nombre = "Vanina"
edad = 30
ciudad = "Asuncion"
print(nombre, edad, ciudad)

#Suma
cantidad_de_manzanas = 25
cantidad_de_naranjas = 10
cantidad_de_frutas = cantidad_de_manzanas + cantidad_de_naranjas
print(cantidad_de_frutas)

# Resta
frutas_vendidas = 15
frutas_restantes = cantidad_de_frutas - frutas_vendidas
print(frutas_restantes)

#Challenge 3
nombre_compi = "Rocio"
apellido_compi = "Alvarez"
print(f"Hola. Me llamo {nombre_compi} {apellido_compi}. Mucho Gusto.")


# Challenge 4
total_de_caramelos = int(input("Ingresa la cantidad de caramelos: ")) 
cantidad_de_niños = int(input("Ingresa la cantidad de niños: "))
caramelos_recibidos = total_de_caramelos // cantidad_de_niños
resto_de_golosinas = total_de_caramelos % cantidad_de_niños

print(caramelos_recibidos, resto_de_golosinas)



cdef division():
    div1 = float(input("Escriba un numero decimal, cualquiera: "))
    div2 = float(input("Ingrese otro numero decimal cualquiera:"))
    resultado = div1 // div2
    print(resultado)

division()

# Challenge 5
def sumar():
    num1 = int(input("Ingrese un numero:"))
    num2 = int (int(input("Ingrese otro numero")))
    suma_final = num1 + num2
    print(f"La suma total es de: {suma_final}")

sumar()
sumar()
sumar() 


# Challenge 6
tipo_de_cafe = input("Ingrese su pedido de cafe: ")
dulce_o_no = input("Ingrese si necesita azucar o edulcorante: ")
con_o_sin_lacteos = input("Ingrese si necesita agregado de lacteos: ")

def cafeteria(cafe, azucarado, lacteos):
    print(f"Preparando pedido: {cafe}, con agreado de azucar o edulcorante: {azucarado}, y con agregado de lacteos? {lacteos}")
    print("Cafe listo! ☕")

cafeteria(tipo_de_cafe, dulce_o_no, con_o_sin_lacteos)
'''
#Challege 7

precio_del_producto = float(input("Ingrese el precio del producto: "))
impuesto_global = 0.1

def calcular_total(precio):
    impuesto = precio * impuesto_global
    total = precio + impuesto
    print(f"El precio total es de: {total}")

calcular_total(precio_del_producto)
# Out:
# El precio total es de: 50.05
