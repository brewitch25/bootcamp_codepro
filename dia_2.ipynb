# %%
'''
# Challenge 1

edad = int(input("Ingrese su edad:"))

if edad < 18:
    print("Acceso denegado - Solo zona kids 🎈")
elif edad < 21:
    print("Acceso permitido - No puede comprar bebidas alcoholicas 🎟️")
else:
    print("Acceso total — Disfruta el festival ")


# Challenge 2

temperatura_usuario = int(input("Ingrese la temperatura en °C: "))

print(f"La temperatura ingresada es de: {temperatura_usuario}")

def rango_temp(temperatura):
    if temperatura >= -10 and temperatura <= 13:
        print("Ro'y koko")
    elif temperatura >= 14 and temperatura <= 23:
        print("Refresca'i")
    elif temperatura >= 24 and temperatura <= 28:
        print("Oikoite")
    elif temperatura >= 29 and temperatura <= 45:
        print("Hakurooo!")
    else:
        print("Ñamano mba'e!")

rango_temp(temperatura_usuario)



# Challenge 3

contraseña = "asdf"

while True:
    contraseña_introducida = input("Ingrese su contraseña: ")
    if contraseña_introducida == contraseña:
        print(f"La contraseña es correcta {contraseña_introducida}")
        break
    else: 
        print("Contraseña Incorrecta")


password = 456
password_user = int(input("Ingrese su contraseña numerica"))

while password != password_user:
    print("Wrong password! Try again")


print("Correct password! ")


# Challenge 4

animales = ["gato", "conejo", "perro", "loro", "raton"]

#Agregar
animales.append("tortuga")
#print(animales)

#Modificar
animales.remove("perro")
#print(animales)    

#Eliminar
animales.pop(3)
print(animales)

# Challenge 5

for iterador in range(10):
    iterador *= 2
    print(iterador)

# Challenge 6

marcas = ["axe", "doritos", "arcor", "xiaomi", "mitsubishi"]

for elemento in marcas:
   # print(elementos)
    longuitud = len(elemento)
    if longuitud >= 6:
        #print(longuitud)
        print(f"La marcas con mas de 6 letras son: {elemento}")
'''

# Challenge 7

frase_usuario = input("Ingrese la frase que desee: ")

for caracter in frase_usuario:
    #print(caracter)
    for letra in caracter:
       # print(letra)
        if letra == "o":
            print(f"Aqui hay una palabra con la letra {letra}")
# Out:
# Aqui hay una palabra con la letra o
# Aqui hay una palabra con la letra o
# Aqui hay una palabra con la letra o
# Aqui hay una palabra con la letra o
