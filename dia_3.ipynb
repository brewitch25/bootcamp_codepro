# %%
'''
# Challenge 1

def prueba():
    palabra = "Palabra"
    print(palabra)

prueba()

# Challenge 2 

#usuario_1 = input("Ingrese una letra: ")
#usuario_2 = input("Ingrese otra letra: ")

def iguales(letra1, letra2):
    if letra1 == letra2:
        print("Las letras son iguales")

    else:
        print("Las letras son diferentes")

iguales("a", "a")
iguales("a", "n")


# Challenge 3

palabra_usuario = input("Ingrese una palabra: ")
numero_usuario = int(input("Ingrese un numero: "))
                     
def comparacion(letra, numero):
    longitud = len(letra)
    if longitud == numero:
        #print("La palabra tiene la misma cantidad de letras que el numero ingresado")
        return True
    else:
        #print("La palabra no tiene la misma cantidad que el numero ingresado")
        return False

comparar_palabra_numero = comparacion(palabra_usuario, numero_usuario)
print(comparar_palabra_numero)


#Challenge 4 

# Crear una lista vacia para guardar las palabras que se va agregando por cada input del ususario
palabras_ingresadas = []
for i in range(3):  # Aca se repite el proceso 3 veces, se solicitas 3 veces al usuario que ponga una palabra
    usuario = input("Ingrese una palabra: ")   # Aca se solicita que el usuario agregue la palabra
    lista_usuario = list(usuario)              # Aca se convierte en lista la palabra agregada por el usuario
    palabras_ingresadas.append(lista_usuario)  # Aca se agrega la palabra(en formato de lista) a la lista vacia 
                                               # "palabras_ingresadas"
    print(palabras_ingresadas)      #Aca se imprime la lista de palabras guardadas en la variable "palabras_ingresadas"

# Challenge 5
lista_usuario = [['h', 'o', 'l', 'i', 's'], ['h', 'e', 'l', 'l', 'o'], ['h', 'a', 'l', 'l', 'o']]

def separar():
    for i in lista_usuario:
        print(i)
        
separar()
'''
# Out:
# ['h', 'o', 'l', 'i', 's']
# ['h', 'e', 'l', 'l', 'o']
# ['h', 'a', 'l', 'l', 'o']
