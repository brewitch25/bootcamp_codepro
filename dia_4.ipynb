# %%
"""
# Challenge 1

dicc_vacio = {} 
lista_claves = ["Nombre:", "Edad: ", "Sexo: ", "Telefono: ", "Correo electronico: "]
for i in len(lista_claves): 
    dicc_vacio[lista_claves[i]] = print("Ingrese ")



# Challenge 2 

dicc_usuario = {}

# En esta funcion se crea el diccionario con el key value
def crear():
    clave = print(input("Que dato desea ingresar?: "))   # Se crea la clave
    valor = print(input("Que valor desea agregar a la clave: "))   #Se crea el valor
    dicc_usuario[clave] = valor   # Se agrega al diccionario vacio
def modificar():   
    dato = input("Que clave desea moficiar?")
    if dato in dicc_usuario.keys():
        dicc_usuario[dato] = input("Valor a agregar")
    else: 
        print("Clave no encontrada, vuelva a ingresar")
def eliminar():
    clave = input("Ingrese el dato a eliminar")
    del dicc_usuario[clave]



while True:
    usuario_accion = input("Que desea hacer? 1.Crear 2.Modificar 3.Eliminar")
    if usuario_accion == "1":
        crear()
    elif usuario_accion == "2":
        modificar()
    elif usuario_accion == "3":
        eliminar()
    else:
        print(f"Su tarjeta personal contiene: {dicc_usuario}")
        break
        """
# Challenge 3

agenda_contactos = {
                    "Bretta":{"Nombre": "Bretta", "Numero de telefono":"0985462598"},
                    "Otter":{"Nombre":"Otter", "Numero de telefono":"0985452378"}
}
#print(agenda_contactos)
# Crear
clave = "Filomeno"
valor = {"Nombre":"Filomeno","Numero de telefono":"0995782154"}
agenda_contactos[clave] = valor
#print(agenda_contactos)
 # Modificar
agenda_contactos["Bretta"] = {"Nombre": "Peye", "Numero de telefono":"0985462598"}
print(agenda_contactos)
# Out:
# {'Bretta': {'Nombre': 'Peye', 'Numero de telefono': '0985462598'}, 'Otter': {'Nombre': 'Otter', 'Numero de telefono': '0985452378'}, 'Filomeno': {'Nombre': 'Filomeno', 'Numero de telefono': '0995782154'}}
