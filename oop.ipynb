# %%
"""
# Challenge 1 
class Animales:
    especie = "Ave"
    def __init__(self, nombre, color):
        self.nombre = nombre
        self.color = color
    def cantar(self):
        print(f"El {self.nombre}, canta muy bonito")

alonsito = Animales("Hornero", "Marron")
pancho = Animales("Loro", "Verde")

print(f"Me llamo: {alonsito.nombre}, mi color es: {alonsito.color}")
print(f"Me llamo: {pancho.nombre}, mi color es de: {pancho.color}")


# Challenge 2
class Gato:
    def __init__(self, nombre):
        self.nombre = nombre
    def comer(self):
        print(f"Cuando le llamo a {self.nombre}, se acerca a comer")
    def peso(self, kg):
        self.kg = kg
        print(f"{self.nombre}, tiene un peso de:{self.kg} kg")
    
peye = Gato("Bretta")
peye.comer()
peye.peso(5)

# Challenge 3

class Masa():
    harina = 200
    leche = 200
    huevo = 4
    azucar = 100
    manteca = 100


class Medialunas(Masa):
    def __init__(self, relleno):
        self.relleno = relleno
    def pedido_medialunas(self):
        print(f"El pedido de medialunas sale con relleno de: {self.relleno}")

class Alfajores(Masa):
    def __init__(self, sabor):
        self.sabor = sabor
    def sabor_alfajor(self)
        #self.sabor = sabor
        print(f"El alfajor es de sabor: {self.sabor}")

# Medialunas
mi_medialuna = Medialunas("Guayaba")
mi_otra_medialuna = Medialunas("Dulce de leche")
mi_medialuna.pedido_medialunas()
mi_otra_medialuna.pedido_medialunas()

# Alfajores
mi_alfajor = Alfajores()
mi_otro_alfajor = Alfajores()
mi_alfajor.sabor_alfajor("Chocolate")
mi_otro_alfajor.sabor_alfajor("Mani")


# Challenge 4
class Villano():
    def __init__(self, nombre):
        self.nombre = nombre
    def super_poder_malo(self):
        print(f"Mi nombre es: {self.nombre}, mi pricipal poder es controlar mentes")

class Heroe():
    def __init__(self, supernombre):
        self.supernombre = supernombre
    def super_poder(self):
        print(f"Yo me llamo: {self.supernombre}, y mi superpoder es el cambiar de forma")        

malo = Villano("MaloMan")
bueno = Heroe("Super GoodBoy!")
malo.super_poder_malo()
bueno.super_poder()
"""
# Out:
# Mi nombre es: MaloMan, mi pricipal poder es controlar mentes
# Yo me llamo: Super GoodBoy!, y mi superpoder es el cambiar de forma
